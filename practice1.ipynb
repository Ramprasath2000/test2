# %%
import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET
from datetime import datetime
import zipfile

def log(message, log_file):
    """Log messages to a log file with a timestamp."""
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    with open(log_file, 'a') as f:
        f.write(f"[{timestamp}] {message}\n")

# def unzip_file(zip_path, extract_to):
#     """Unzip the file to the specified directory."""
#     if not os.path.exists(extract_to):
#         os.makedirs(extract_to)  # Create the folder if it doesn't exist
#     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to)

def extract_csv(file_path):
    """Extract data from a CSV file."""
    return pd.read_csv(file_path)

def extract_json(file_path):
    """Extract data from a JSON file."""
    return pd.read_json(file_path)

def extract_xml(file_path):
    """Extract data from an XML file."""
    tree = ET.parse(file_path)
    root = tree.getroot()
    all_data = []
    for child in root:
        data = {element.tag: element.text for element in child}
        all_data.append(data)
    return pd.DataFrame(all_data)

def extract_data(data_folder):
    """Extract data from multiple file formats."""
    extracted_data = pd.DataFrame()
    for file in glob.glob(f"{data_folder}/*"):
        if file.endswith('.csv'):
            data = extract_csv(file)
        elif file.endswith('.json'):
            data = extract_json(file)
        elif file.endswith('.xml'):
            data = extract_xml(file)
        else:
            continue
        extracted_data = pd.concat([extracted_data, data], ignore_index=True)
    return extracted_data

def transform_data(data):
    """Transform the data (convert heights and weights)."""
    data['Height'] = data['Height'].astype(float) * 0.0254  # inches to meters
    data['Weight'] = data['Weight'].astype(float) * 0.453592  # pounds to kilograms
    return data

def load_data(data, output_file):
    """Save the transformed data to a CSV file."""
    data.to_csv(output_file, index=False)

def main():
    # Paths
    #zip_file = './source.zip'
    data_folder = r'C:\Users\Ram\Desktop\ME36'
    log_file = r'C:\Users\Ram\Desktop\ME36\log_file.txt'
    output_file = r'C:\Users\Ram\Desktop\ME36/transformed_data3.csv'

    # Clear log file
    if os.path.exists(log_file):
        os.remove(log_file)

    # # Unzipping step
    # log("Unzipping the file.", log_file)
    # unzip_file(zip_file, data_folder)

    log("ETL process started.", log_file)
    
    try:
        # Extraction
        log("Starting data extraction.", log_file)
        extracted_data = extract_data(data_folder)
        log("Data extraction completed.", log_file)
        print(extracted_data)

        # Transformation
        log("Starting data transformation.", log_file)
        transformed_data = transform_data(extracted_data)
        print(transformed_data)
        log("Data transformation completed.", log_file)

        # Loading
        log("Starting data loading.", log_file)
        load_data(transformed_data, output_file)
        log("Data loading completed.", log_file)

        log("ETL process completed successfully.", log_file)

    except Exception as e:
        log(f"ETL process failed: {e}", log_file)

if __name__ == "__main__":
    main()

# %%
import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET
from datetime import datetime
import zipfile

def log(message, log_file):
    """Log messages to a log file with a timestamp."""
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    with open(log_file, 'a') as f:
        f.write(f"[{timestamp}] {message}\n")



def extract_csv(file_path):
    """Extract data from a CSV file."""
    try:
        return pd.read_csv(file_path)
    except Exception as e:
        print(f"Error reading CSV file {file_path}: {e}")
        return pd.DataFrame()

def extract_json(file_path):
    """Extract data from a JSON file."""
    try:
        return pd.read_json(file_path, lines=True)  # Use lines=True for JSON lines format
    except ValueError as e:
        print(f"Error reading JSON file {file_path}: {e}")
        return pd.DataFrame()

def extract_xml(file_path):
    """Extract data from an XML file."""
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()
        all_data = []
        for child in root:
            data = {element.tag: element.text for element in child}
            all_data.append(data)
        return pd.DataFrame(all_data)
    except ET.ParseError as e:
        print(f"Error reading XML file {file_path}: {e}")
        return pd.DataFrame()

def extract_data(data_folder):
    """Extract data from multiple file formats."""
    extracted_data = pd.DataFrame()
    for file in glob.glob(f"{data_folder}/*"):
        print(f"Processing file: {file}")  # Print each file being processed
        try:
            if file.endswith('.csv'):
                data = extract_csv(file)
            elif file.endswith('.json'):
                data = extract_json(file)
            elif file.endswith('.xml'):
                data = extract_xml(file)
            else:
                continue
            extracted_data = pd.concat([extracted_data, data], ignore_index=True)
        except Exception as e:
            print(f"Error processing file {file}: {e}")
    
    # Normalize column names to lowercase for consistency
    extracted_data.columns = [col.lower() for col in extracted_data.columns]

        # Remove duplicates
    extracted_data = extracted_data.drop_duplicates()

    return extracted_data


def transform_data(data):
    """Transform the data (convert heights and weights)."""
    try:
        data['height'] = data['height'].astype(float) * 0.0254  # inches to meters
        data['weight'] = data['weight'].astype(float) * 0.453592  # pounds to kilograms
    except KeyError as e:
        print(f"Missing column during transformation: {e}")
    except ValueError as e:
        print(f"Data conversion error during transformation: {e}")
    return data

def load_data(data, output_file):
    """Save the transformed data to a CSV file."""
    try:
        data.to_csv(output_file, index=False)
    except Exception as e:
        print(f"Error saving data to {output_file}: {e}")

def main():
    # Paths
   
    data_folder = r'C:\Users\Ram\Desktop\ME36'
    log_file = r'C:\Users\Ram\Desktop\ME36\log_file.txt'
    output_file = r'C:\Users\Ram\Desktop\ME36\transformed_data3.csv'

    # Clear log file
    if os.path.exists(log_file):
        os.remove(log_file)


    log("ETL process started.", log_file)
    
    try:
        # Extraction
        log("Starting data extraction.", log_file)
        extracted_data = extract_data(data_folder)
        log("Data extraction completed.", log_file)
							 

        # Print extracted data for debugging
        print("Extracted Data:")
        print(extracted_data.head())

        # Transformation
        log("Starting data transformation.", log_file)
        transformed_data = transform_data(extracted_data)
							   
        log("Data transformation completed.", log_file)

        # Print transformed data for debugging
        print("Transformed Data:")
        print(transformed_data.head())

        # Loading
        log("Starting data loading.", log_file)
        load_data(transformed_data, output_file)
        log("Data loading completed.", log_file)

        log("ETL process completed successfully.", log_file)

    except Exception as e:
        log(f"ETL process failed: {e}", log_file)
        print(f"ETL process failed: {e}")

if __name__ == "__main__":
    main()
# Out:
# Processing file: C:\Users\Ram\Desktop\ME36\helloworld.ipynb
# Processing file: C:\Users\Ram\Desktop\ME36\log_file.txt
# Processing file: C:\Users\Ram\Desktop\ME36\source1.csv
# Processing file: C:\Users\Ram\Desktop\ME36\source1.json
# Processing file: C:\Users\Ram\Desktop\ME36\source1.xml
# Processing file: C:\Users\Ram\Desktop\ME36\source2.csv
# Processing file: C:\Users\Ram\Desktop\ME36\source2.json
# Processing file: C:\Users\Ram\Desktop\ME36\source2.xml
# Processing file: C:\Users\Ram\Desktop\ME36\source3.csv
# Processing file: C:\Users\Ram\Desktop\ME36\source3.json
# Processing file: C:\Users\Ram\Desktop\ME36\source3.xml
# Processing file: C:\Users\Ram\Desktop\ME36\test.ipynb
# Processing file: C:\Users\Ram\Desktop\ME36\transformed_data2.csv
# Processing file: C:\Users\Ram\Desktop\ME36\transformed_data3.csv
# Extracted Data:
#     name height  weight
# 0   alex  65.78  112.99
# 1   ajay  71.52  136.49
# 2  alice   69.4  153.03
# 3   ravi  68.22  142.34
# 4    joe  67.79   144.3
# Transformed Data:
#     name    height     weight
# 0   alex  1.670812  51.251360
# 1   ajay  1.816608  61.910772
# 2  alice  1.762760  69.413184
# 3   ravi  1.732788  64.564285
# 4    joe  1.721866  65.453326

# %%
import re

def extract_emails_and_dates_v2(log_file_path):
    # Updated regex patterns
    email_regex = r'[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}'
    date_regex = r'\b(?:[A-Za-z]{3},?\s+)?(?:\d{1,2}\s+[A-Za-z]{3}\s+\d{4}\s+\d{2}:\d{2}:\d{2}(?:\s+[+-]\d{4})?)|(?:\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2})\b'
    
    extracted_data = []

    with open(log_file_path, 'r') as file:
        for line in file:
            # Extract email addresses
            emails = re.findall(email_regex, line)
            # Extract dates
            dates = re.findall(date_regex, line)
            
            # Pair emails and dates
            for email in emails:
                if dates:  # If dates are found, pair each email with each date
                    for date in dates:
                        extracted_data.append({'email': email, 'date': date})
                else:  # If no date is found, store email with None
                    extracted_data.append({'email': email, 'date': None})

    return extracted_data

# Test the function
log_file_path = r'C:\Users\Ram\Downloads\mbox.txt'  # Replace with the actual log file path
data = extract_emails_and_dates_v2(log_file_path)
print(data)
# Out:
# [{'email': 'stephen.marquard@uct.ac.za', 'date': None}, {'email': 'postmaster@collab.sakaiproject.org', 'date': None}, {'email': '200801051412.m05ECIaH010327@nakamura.uits.iupui.edu', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': 'Sat,  5 Jan 2008 14:13:33 +0000'}, {'email': 'source@collab.sakaiproject.org', 'date': 'Sat, 5 Jan 2008 09:12:19 -0500'}, {'email': 'source@collab.sakaiproject.org', 'date': 'Sat, 5 Jan 2008 09:12:18 -0500'}, {'email': 'stephen.marquard@uct.ac.za', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'stephen.marquard@uct.ac.za', 'date': None}, {'email': 'stephen.marquard@uct.ac.za', 'date': None}, {'email': 'louis@media.berkeley.edu', 'date': None}, {'email': 'postmaster@collab.sakaiproject.org', 'date': None}, {'email': '200801042308.m04N8v6O008125@nakamura.uits.iupui.edu', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri,  4 Jan 2008 23:10:10 +0000'}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri, 4 Jan 2008 18:08:57 -0500'}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri, 4 Jan 2008 18:08:57 -0500'}, {'email': 'louis@media.berkeley.edu', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'louis@media.berkeley.edu', 'date': None}, {'email': 'louis@media.berkeley.edu', 'date': None}, {'email': 'zqian@umich.edu', 'date': None}, {'email': 'postmaster@collab.sakaiproject.org', 'date': None}, {'email': '200801042109.m04L92hb007923@nakamura.uits.iupui.edu', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri,  4 Jan 2008 21:10:14 +0000'}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri, 4 Jan 2008 16:09:02 -0500'}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri, 4 Jan 2008 16:09:02 -0500'}, {'email': 'zqian@umich.edu', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'zqian@umich.edu', 'date': None}, {'email': 'zqian@umich.edu', 'date': None}, {'email': 'rjlowe@iupui.edu', 'date': None}, {'email': 'postmaster@collab.sakaiproject.org', 'date': None}, {'email': '200801042044.m04Kiem3007881@nakamura.uits.iupui.edu', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri,  4 Jan 2008 20:45:52 +0000'}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri, 4 Jan 2008 15:44:40 -0500'}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri, 4 Jan 2008 15:44:40 -0500'}, {'email': 'rjlowe@iupui.edu', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'rjlowe@iupui.edu', 'date': None}, {'email': 'rjlowe@iupui.edu', 'date': None}, {'email': 'zqian@umich.edu', 'date': None}, {'email': 'postmaster@collab.sakaiproject.org', 'date': None}, {'email': '200801042001.m04K1cO0007738@nakamura.uits.iupui.edu', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri,  4 Jan 2008 20:02:50 +0000'}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri, 4 Jan 2008 15:01:38 -0500'}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri, 4 Jan 2008 15:01:38 -0500'}, {'email': 'zqian@umich.edu', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'zqian@umich.edu', 'date': None}, {'email': 'zqian@umich.edu', 'date': None}, {'email': 'zqian@umich.edu', 'date': None}, {'email': 'rjlowe@iupui.edu', 'date': None}, {'email': 'postmaster@collab.sakaiproject.org', 'date': None}, {'email': '200801041948.m04JmdwO007705@nakamura.uits.iupui.edu', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': None}, {'email': 'source@collab.sakaiproject.org', 'date': 'Fri,  4 Jan 2008 19:49:51 +0000'}, {'email': 'source@collab.sakaiproject.org ...

# %%
from datetime import datetime

def transform_data(extracted_data):
    transformed_data = []
    for record in extracted_data:
        try:
            date = datetime.strptime(record['date'], '%Y-%m-%d %H:%M:%S')
            transformed_data.append({
                'email': record['email'],
                'date': date.strftime('%Y-%m-%d %H:%M:%S')
            })
        except ValueError:
            continue  # Skip invalid dates
    return transformed_data

# Test the function
transformed_data = transform_data(data)
print(transformed_data)
# Out:
# [{'email': 'hu2@iupui.edu', 'date': '2007-12-20 15:25:38'}, {'email': 'hu2@iupui.edu', 'date': '2007-12-20 21:26:28'}, {'email': 'david.horwitz@uct.ac.za', 'date': '2008-01-04 13:05:51'}, {'email': 'josrodri@iupui.edu', 'date': '2007-12-28 23:44:24'}, {'email': 'josrodri@iupui.edu', 'date': '2007-12-12 21:40:33'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-12-17 17:11:08'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-09-12 16:17:59'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-12 15:53:46'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-17 12:16:42'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-15 01:11:33'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-11 14:26:27'}, {'email': 'cwen@iupui.edu', 'date': '2007-11-29 14:35:46'}, {'email': 'cwen@iupui.edu', 'date': '2007-10-31 13:15:28'}, {'email': 'cwen@iupui.edu', 'date': '2007-10-29 14:30:26'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-12-17 15:20:23'}, {'email': 'rjlowe@iupui.edu', 'date': '2007-12-17 10:53:09'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-12-17 16:29:35'}, {'email': 'cwen@iupui.edu', 'date': '2008-01-03 13:06:41'}, {'email': 'david.horwitz@uct.ac.za', 'date': '2007-09-26 05:26:53'}, {'email': 'david.horwitz@uct.ac.za', 'date': '2007-11-14 01:53:07'}, {'email': 'david.horwitz@uct.ac.za', 'date': '2007-12-20 10:00:05'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-12 15:45:36'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-12 10:05:59'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-12-12 10:10:30'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-12 10:41:58'}, {'email': 'joshua.ryan@asu.edu', 'date': '2007-09-21 20:02:50'}, {'email': 'kimsooil@bu.edu', 'date': '2007-07-16 13:53:33'}, {'email': 'ian@caret.cam.ac.uk', 'date': '2007-07-17 07:54:46'}, {'email': 'josrodri@iupui.edu', 'date': '2007-12-28 21:15:33'}, {'email': 'zqian@umich.edu', 'date': '2007-12-31 21:51:23'}, {'email': 'gsilver@umich.edu', 'date': '2007-12-30 04:07:07'}, {'email': 'josrodri@iupui.edu', 'date': '2007-12-18 21:51:48'}, {'email': 'ian@caret.cam.ac.uk', 'date': '2007-12-07 18:03:07'}, {'email': 'zqian@umich.edu', 'date': '2007-11-20 23:08:48'}, {'email': 'zqian@umich.edu', 'date': '2007-12-31 23:22:03'}, {'email': 'zqian@umich.edu', 'date': '2007-12-21 19:19:37'}, {'email': 'joshua.ryan@asu.edu', 'date': '2007-11-30 00:20:17'}, {'email': 'david.horwitz@uct.ac.za', 'date': '2007-12-21 16:08:28'}, {'email': 'chmaurer@iupui.edu', 'date': '2007-12-18 15:41:00'}, {'email': 'bkirschn@umich.edu', 'date': '2007-12-21 01:36:58'}, {'email': 'david.horwitz@uct.ac.za', 'date': '2007-12-21 10:30:23'}, {'email': 'david.horwitz@uct.ac.za', 'date': '2007-12-21 10:19:00'}, {'email': 'rjlowe@iupui.edu', 'date': '2007-12-17 21:11:47'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-17 12:29:24'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-15 14:51:16'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-15 17:10:25'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-15 17:45:57'}, {'email': 'cwen@iupui.edu', 'date': '2007-12-15 17:57:40'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-12-17 15:20:23'}, {'email': 'bkirschn@umich.edu', 'date': '2007-12-14 16:16:09'}, {'email': 'jbush@rsmart.com', 'date': '2007-12-14 15:39:41'}, {'email': 'aaronz@vt.edu', 'date': '2007-12-11 02:52:59'}, {'email': 'aaronz@vt.edu', 'date': '2007-12-10 13:26:21'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-12-17 11:56:03'}, {'email': 'rjlowe@iupui.edu', 'date': '2007-12-17 10:53:09'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-12-12 10:10:30'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-12-13 09:29:44'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-12-13 09:29:44'}, {'email': 'wagnermr@iupui.edu', 'date': '2007-12-13 09:29:44'}, {'email': 'zqian@umich.edu', 'date': '2007-12-13 15:05:48'}, {'email': 'jimeng@umich.edu', 'date': '2007-12-13 08:08:24'}, {'email': 'jimeng@umich.edu', 'date': '2007-12-13 11:08:24'}, {'email': 'ian@caret.cam.ac.uk', 'date': '2007-12-13 04:46:48'}, {'email': 'ian@caret.cam.ac.uk', 'date': ' ...

# %%
# !python -m pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.10.1-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading pymongo-4.10.1-cp312-cp312-win_amd64.whl (926 kB)
#    ---------------------------------------- 0.0/926.7 kB ? eta -:--:--
#    ---------------------------------------- 926.7/926.7 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1
# WARNING: pymongo 4.10.1 does not provide the extra 'srv'
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://ram:2000@cluster0.5dmxi.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://ram:2000@cluster0.5dmxi.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
#mongodb+srv://ram:<db_password>@cluster0.5dmxi.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
def save_to_mongodb(data, db_name='logs', collection_name='user_history'):
    client = MongoClient(uri)
    db = client[db_name]
    collection = db[collection_name]
    collection.insert_many(data)
    print(f"Inserted {len(data)} records into MongoDB collection '{collection_name}'.")

# Test the function
save_to_mongodb(transformed_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#      11     print(f"Inserted {len(data)} records into MongoDB collection '{collection_name}'.")
#      13 # Test the function
# ---> 14 save_to_mongodb(transformed_data)
#
# NameError: name 'transformed_data' is not defined

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\ram\appdata\local\programs\python\python312\lib\site-packages (9.1.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo import MongoClient
import mysql.connector

def fetch_from_mongodb(mongo_uri='mongodb+srv://ram:2000@cluster0.5dmxi.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0', db_name='logs', collection_name='user_history'):
    client = MongoClient(mongo_uri)
    db = client[db_name]
    collection = db[collection_name]
    return list(collection.find({}, {'_id': 0}))

def save_to_mysql(data, table_name='user_history'):
    conn = mysql.connector.connect(
        host="localhost",
        port=3306,  # Default MySQL port
        user="root",  
        password="",  
        database="test" 
    )
    cursor = conn.cursor()
    
    # Create table
    cursor.execute(f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            id INT AUTO_INCREMENT PRIMARY KEY,
            email VARCHAR(255) NOT NULL,
            date DATETIME NOT NULL
        );
    """)

    # Insert data
    cursor.executemany(f"""
        INSERT INTO {table_name} (email, date) VALUES (%s, %s);
    """, [(record['email'], record['date']) for record in data])

    conn.commit()
    conn.close()
    print(f"Inserted {len(data)} records into MySQL table '{table_name}'.")

# Test the function
mongodb_data = fetch_from_mongodb()
save_to_mysql(mongodb_data)
# Out:
# Inserted 343 records into MySQL table 'user_history'.

# %%
query = "SELECT DISTINCT email FROM user_history;"
cursor.execute(query)
unique_emails = cursor.fetchall()
print(unique_emails)

# %%
a = "helloo"
length = len(a)
if length % 2 == 1 :
    mid = length // 2
    result = a[:mid] + "*" + a[mid+1:]
    print(result)
else :
    mid1 = length // 2 -1
    mid2 = length // 2
    result = a[:mid1] + "**" + a[mid2+1:]
    print(result)
# Out:
# he**oo

# %%
n = 7
a = [1, 2 , 3 ,5, 4, 6, 7]
a.sort()
print(a)
for i in range(n-1, n-4, -1):
    print(a[i])
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# 7
# 6
# 5

# %%
n = int(input())
a = list(map(int, input().split()))
empty = []
frequency = []
result = []
for i in range(n):
    if a[i] and a[i] not in empty:
        empty.append(a[i])
        frequency.append(1)
    else:
        frequency[empty.index(a[i])] += 1
print(empty)
print(frequency)
print("mininum", min(frequency))
for i in range(len(frequency)):
    if frequency[i] < min(frequency):
        result.append(empty[i])
print(result)
# Out:
# [99]
# [5]
# mininum 5
# []

# %%
n = 5
a= [4, 0, 2,  1, 3]
result =[]
for i in a :
    print(i)
    result.append(a[i])
print(result)
# Out:
# 4
# 0
# 2
# 1
# 3
# [3, 4, 2, 0, 1]

# %%
n = int(input())
a = list(map(int, input().split()))
result = []

for i in range(n):
    summ =0
    for j in range(n-1, n-4, -1):
        print(a[j])
        summ +=  a[j]
    subb = a[i] - summ
        #print(summ)
    #result.append(subb)
print(result)
# Out:
# 11
# 12
# 75
# 11
# 12
# 75
# 11
# 12
# 75
# 11
# 12
# 75
# 11
# 12
# 75
# [-3, -13, -23, -86, -87]

# %%
print(0%2)
# Out:
# 0

# %%
s = input()
str1 = ""
str2 =""
for i in range(len(s)):
    if i % 2 == 0:
        print(s[i])
        str1 = str1 + s[i]
    else :
        str2 = str2 + s[i]
print(str1+ " " + str2)
# Out:
# R
# m
# Rm a

# %%
a = '2134'
result =[]
for i in a :
    if int(i) % 2 == 1 :
        result.append(i)
if result == [] :
    print(-1)
print(result)
# Out:
# ['1', '3']

# %%
#exploring the usage of tuple
#list which contains both string and integer values
a = ['Karthik' ,'23000' ,'rohan' ,'81734' ,'varshini',  '12343']
#having empty list
conv = []
#to convert the integer values seperately we use steps as 2
for i in range (0,len(a),2):
    #appending the tuples into the list
    conv.append((a[i], int(a[i+1])))
print("before sorting\n",conv)
#to return the position of the tuple we want
def get_salary(tupp):
    return(tupp[1])
#key takes only the values return from funtions.  Here we are sorting based on the value return by the funtion get_salary(will return the salary, which is in the tuple)
conv.sort(key= get_salary)
print("After sorting \n",conv)
# Out:
# before sorting
#  [('Karthik', 23000), ('rohan', 81734), ('varshini', 12343)]
# After sorting
#  [('varshini', 12343), ('Karthik', 23000), ('rohan', 81734)]

# %%
#exploring the usage of tuple
#list which contains both string and integer values
n =  int(input())
a = list(map(str,input().split()))
#having empty list
conv = []
#to convert the integer values seperately we use steps as 2
for i in range (0,len(a),2):
    #appending the tuples into the list
    conv.append((a[i], int(a[i+1])))
#print("before sorting\n",conv)
#to return the position of the tuple we want
def get_salary(tupp):
    return(tupp[1])
#key takes only the values return from funtions.  Here we are sorting based on the value return by the funtion get_salary(will return the salary, which is in the tuple)
conv.sort(key= get_salary)
print(conv)
# Out:
# [('Karthik', 23000), ('rohan', 81734), ('varshini', 12343)]

# %%
n =5
a =[2004, 1999, 2019, 2009, 2014]
b = ["JDU", "JDU", "CON", "JDU", "CON"]
# srted = []
# for i in range(len(a)):
#     srted.append((a[i], b[i]))
# def arrange(val):
#     return(val[0])
# srted.sort(key = arrange)
# print(srted)
# for i in srted :
#     if i[]
srted = sorted(zip(a, b))
print(srted)
for i in range (len(a)-1):
    if srted[i][1] != srted[i+1][1]:
        print(srted[i+1][0])
        break
# Out:
# [(1999, 'JDU'), (2004, 'JDU'), (2009, 'JDU'), (2014, 'CON'), (2019, 'CON')]
# 2014

# %%
# Input
size = int(input())
years = list(map(int, input().split()))
parties = input().split()

# Find the year of transition
for i in range(1, size):
    if parties[i] != parties[i - 1]:
        print(years[i])
        break
# Out:
# 2019

# %%
M, N = map(int, input().split())
matrix = []

# Reading the matrix
for _ in range(M):
    row = list(map(int, input().split()))
    matrix.extend(row)
print(matrix)
# Out:
# [1, 1, 1, 1, 1, 1]

# %%
m, n = map(int,input().split())
a = []
for i in range(m):
    a.extend(map(int,input().split()))
print(a)
# Out:
# [3, 4, 5]
